# %%
import pandas as pd
import numpy as np
from sqlalchemy import Column, String, Integer, Text
from geoalchemy2 import Geometry
from sqlalchemy.orm import sessionmaker
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base

# %%
user_name = 'l01-4'
#use the file way of storing password or set passw to your password
with open("l01-4_password.txt") as f:
    passw = f.read()

# %% [markdown]
# # Transit LRT Stations
# ## Source: City of Calgary's Open Data Portal
# Changelog for Data Export to SQL Table
# - Include
# STATIONNAM	LEG	DIRECTION	DIST_NB	DIST_SB	DIST_EB	DIST_WB	ROUTE	STATUS	the_geo
#
# - Make the_geom a GEOMETRY data type, rename to LRT_POINT so it is more meaningful
# - review names, set to a naming standar - change to uppercase so it is consistent
# -- rename STATIONNAM to STATION_NMEd
# - primary key has to be createas STATION_ID d and auto-generat number, Open Data Calgary or Calgary Transit website does not provide a unique identifer for each LRT Stationeions
#
# Link: https://data.calgary.ca/Transportation-Transit/Transit-LRT-Stations/2axz-xm4q/about_data

# %%
df_LRT = pd.read_csv("Transit_LRT_Stations_20240229.csv")
df_LRT.head(5)
# Out:
#               STATIONNAM        LEG    DIRECTION  DIST_NB  DIST_SB  DIST_EB  \
# 0   45 Street SW Station       West    West/East      NaN      NaN      NaN
# 1        Sirocco Station       West    West/East      NaN      NaN      NaN
# 2      City Hall Station  DTWestbnd         West      NaN      NaN    200.0
# 3  1st Street SW Station  DTWestbnd         West      0.0      0.0    467.0
# 4      Dalhousie Station         NW  North/South   3966.0   2732.0      0.0
#
#    DIST_WB    ROUTE   STATUS                         the_geom
# 0      NaN      202  Current  POINT (-114.1541947 51.0379605)
# 1      NaN      202  Current  POINT (-114.1690442 51.0383797)
# 2      NaN  201/202  Current  POINT (-114.0570028 51.0463789)
# 3    439.0  201/202  Current  POINT (-114.0640924 51.0465842)
# 4      0.0      201  Current  POINT (-114.1605254 51.1032838)

# %%
# Rename the 'polygon' column to 'COMMUNITY_BOUNDARY'
df_LRT = df_LRT.rename(columns={'the_geom': 'LRT_POINT'})
df_LRT = df_LRT.rename(columns={'STATIONNAM': 'STATION_NAME'})
# Convert NaN to None
df_LRT.replace({np.nan: None}, inplace=True)
# Rename columns to uppercase
df_LRT.columns = df_LRT.columns.str.upper()
df_LRT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   STATION_NAME  47 non-null     object
#  1   LEG           47 non-null     object
#  2   DIRECTION     47 non-null     object
#  3   DIST_NB       37 non-null     object
#  4   DIST_SB       37 non-null     object
#  5   DIST_EB       36 non-null     object
#  6   DIST_WB       35 non-null     object
#  7   ROUTE         47 non-null     object
#  8   STATUS        47 non-null     object
#  9   LRT_POINT     47 non-null     object
# dtypes: object(10)
# memory usage: 3.8+ KB

# %%
#append the dataset for future Green Line LRT Transit Stations
df_green_lrt = pd.read_csv("Green_Line_Stations_20240319.csv")
# Rename columns to uppercase
df_green_lrt.columns = df_green_lrt.columns.str.upper()
df_green_lrt = df_green_lrt.rename(columns={'NAME': 'STATION_NAME'})
df_green_lrt = df_green_lrt.rename(columns={'POINT': 'LRT_POINT'})
df_green_lrt['STATUS'] = 'Future'
df_green_lrt['LEG'] = 'Green' #placeholder value until final construction
df_green_lrt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   STATION_NAME         29 non-null     object
#  1   INFORMATION          29 non-null     object
#  2   TOD                  29 non-null     object
#  3   UNDERGROUND          29 non-null     object
#  4   STATION TYPE         15 non-null     object
#  5   INTRODUCTION TEXT    29 non-null     object
#  6   NEARBY DESTINATIONS  15 non-null     object
#  7   CONSTRUCTION STAGE   15 non-null     object
#  8   LOCATION             14 non-null     object
#  9   LRT_POINT            29 non-null     object
#  10  STATUS               29 non-null     object
#  11  LEG                  29 non-null     object
# dtypes: object(12)
# memory usage: 2.8+ KB

# %%
# Define the database connection string
database_url = f"mysql+mysqlconnector://{user_name}:{passw}@datasciencedb.ucalgary.ca/{user_name}"

# Create the SQLAlchemy engine
engine = create_engine(database_url, echo=True)  # Set echo to True for debugging

# Test the connection
with engine.connect() as connection:
    result = connection.execute("SELECT 1")
    print(result.scalar())
# Out:
# 2024-03-20 18:01:48,050 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2024-03-20 18:01:48,061 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-03-20 18:01:48,075 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2024-03-20 18:01:48,083 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-03-20 18:01:48,093 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2024-03-20 18:01:48,093 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-03-20 18:01:48,107 INFO sqlalchemy.engine.Engine SELECT 1
# 2024-03-20 18:01:48,109 INFO sqlalchemy.engine.Engine [raw sql] {}
# 1

# %%
# Define the Base class
Base = declarative_base()

class TransitLRTStation(Base):
    __tablename__ = 'transit_lrt_stations'

    STATION_ID = Column(Integer, primary_key=True, autoincrement=True)
    STATION_NAME = Column(Text, default=None)
    LEG = Column(Text, default=None)
    DIRECTION = Column(Text, default=None)
    DIST_NB = Column(Text, default=None)
    DIST_SB = Column(Text, default=None)
    DIST_EB = Column(Text, default=None)
    DIST_WB = Column(Text, default=None)
    ROUTE = Column(Text, default=None)
    STATUS = Column(Text, default=None)
    LRT_POINT = Column(Geometry(geometry_type='POINT', srid=4326), default=None)
    
Base.metadata.create_all(engine)
# Out:
# 2024-03-20 18:01:48,948 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:48,965 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2024-03-20 18:01:48,965 INFO sqlalchemy.engine.Engine [generated in 0.01608s] {'table_schema': 'l01-4', 'table_name': 'transit_lrt_stations'}
# 2024-03-20 18:01:48,974 INFO sqlalchemy.engine.Engine COMMIT

# %%
Session = sessionmaker(bind=engine)
session = Session()

# %%
# Loop through DataFrame rows and insert data into the database
for index, row in df_LRT.iterrows():
    try:
        lrt_station = TransitLRTStation(
            STATION_NAME=row['STATION_NAME'],
            LEG=row['LEG'],
            DIRECTION=row['DIRECTION'],
            DIST_NB=row['DIST_NB'],
            DIST_SB=row['DIST_SB'],
            DIST_EB=row['DIST_EB'],
            DIST_WB=row['DIST_WB'],
            ROUTE=row['ROUTE'],
            STATUS=row['STATUS'],
            LRT_POINT=row['LRT_POINT']
        )
        session.add(lrt_station)
        session.commit()  # Commit the transaction

    except Exception as e:
        print(f"Error in row {index}: {e}")
        print(row)  # Print the entire row for reference
        session.rollback()  # Rollback the transaction to continue with the next row
# Out:
# 2024-03-20 18:01:50,807 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:50,818 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:50,828 INFO sqlalchemy.engine.Engine [generated in 0.01406s] {'STATION_NAME': '45 Street SW Station', 'LEG': 'West', 'DIRECTION': 'West/East', 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': '202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.1541947 51.0379605)'}
# 2024-03-20 18:01:50,844 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:50,855 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:50,863 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:50,868 INFO sqlalchemy.engine.Engine [cached since 0.05353s ago] {'STATION_NAME': 'Sirocco Station', 'LEG': 'West', 'DIRECTION': 'West/East', 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': '202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.1690442 51.0383797)'}
# 2024-03-20 18:01:50,870 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:50,885 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:50,885 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:50,894 INFO sqlalchemy.engine.Engine [cached since 0.07977s ago] {'STATION_NAME': 'City Hall Station', 'LEG': 'DTWestbnd', 'DIRECTION': 'West', 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': 200.0, 'DIST_WB': None, 'ROUTE': '201/202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0570028 51.0463789)'}
# 2024-03-20 18:01:50,903 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:50,914 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:50,919 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:50,919 INFO sqlalchemy.engine.Engine [cached since 0.11s ago] {'STATION_NAME': '1st Street SW Station', 'LEG': 'DTWestbnd', 'DIRECTION': 'West', 'DIST_NB': 0.0, 'DIST_SB': 0.0, 'DIST_EB': 467.0, 'DIST_WB': 439.0, 'ROUTE': '201/202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0640924 51.0465842)'}
# 2024-03-20 18:01:50,930 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:50,943 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:50,952 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:50,953 INFO sqlalchemy.engine.Engine [cached since 0.1394s ago] {'STATION_NAME': 'Dalhousie Station', 'LEG': 'NW', 'DIRECTION': 'North/South', 'DIST_NB': 3966.0, 'DIST_SB': 2732.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.1605254 51.1032838)'}
# 2024-03-20 18:01:50,957 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:50,980 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:50,985 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:50,992 INFO sqlalchemy.engine.Engine [cached since 0.1782s ago] {'STATION_NAME': 'Southland Station', 'LEG': 'SW', 'DIRECTION': 'North/South', 'DIST_NB': 1654.0, 'DIST_SB': 1064.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0765605 50.963571)'}
# 2024-03-20 18:01:51,000 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,014 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,018 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,018 INFO sqlalchemy.engine.Engine [cached since 0.2106s ago] {'STATION_NAME': 'Fish Creek - Lacombe Station', 'LEG': 'SW', 'DIRECTION': 'North/South', 'DIST_NB': 1505.0, 'DIST_SB': 1464.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0730564 50.9231615)'}
# 2024-03-20 18:01:51,030 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,052 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,052 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,058 INFO sqlalchemy.engine.Engine [cached since 0.2448s ago] {'STATION_NAME': 'Centre Street Station', 'LEG': 'DTEastbnd', 'DIRECTION': 'East', 'DIST_NB': 0.0, 'DIST_SB': 0.0, 'DIST_EB': 319.0, 'DIST_WB': 544.0, 'ROUTE': '201/202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0616682 51.0463708)'}
# 2024-03-20 18:01:51,064 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,078 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,086 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,086 INFO sqlalchemy.engine.Engine [cached since 0.2738s ago] {'STATION_NAME': 'Bridgeland Station', 'LEG': 'NE', 'DIRECTION': 'East/West', 'DIST_NB': 0.0, 'DIST_SB': 0.0, 'DIST_EB': 1100.0, 'DIST_WB': 1236.0, 'ROUTE': '202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0403776 51.0490497)'}
# 2024-03-20 18:01:51,094 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,097 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,111 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,119 INFO sqlalchemy.engine.Engine [cached since 0.3055s ago] {'STATION_NAME': '8th Street SW Station', 'LEG': 'DTEastbnd', 'DIRECTION': 'East', 'DIST_NB': 1199.0, 'DIST_SB': 0.0, 'DIST_EB': 205.0, 'DIST_WB': 287.0, 'ROUTE': '201/202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0799562 51.0469197)'}
# 2024-03-20 18:01:51,119 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,133 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,144 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,144 INFO sqlalchemy.engine.Engine [cached since 0.3344s ago] {'STATION_NAME': 'Marlborough Station', 'LEG': 'NE', 'DIRECTION': 'North/South', 'DIST_NB': 1845.0, 'DIST_SB': 1722.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-113.9817163 51.058426)'}
# 2024-03-20 18:01:51,159 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,177 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,177 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,186 INFO sqlalchemy.engine.Engine [cached since 0.3726s ago] {'STATION_NAME': '69 Street SW Station', 'LEG': 'West', 'DIRECTION': 'West/East', 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': '202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.1876094 51.0376451)'}
# 2024-03-20 18:01:51,194 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,210 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,219 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,219 INFO sqlalchemy.engine.Engine [cached since 0.4071s ago] {'STATION_NAME': 'Sunalta Station', 'LEG': 'West', 'DIRECTION': 'West/East', 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': '202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0991346 51.0448181)'}
# 2024-03-20 18:01:51,227 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,232 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,244 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,244 INFO sqlalchemy.engine.Engine [cached since 0.4335s ago] {'STATION_NAME': 'Lions Park Station', 'LEG': 'NW', 'DIRECTION': 'North/South', 'DIST_NB': 1220.0, 'DIST_SB': 923.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.1035911 51.0650408)'}
# 2024-03-20 18:01:51,251 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,269 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,274 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,277 INFO sqlalchemy.engine.Engine [cached since 0.4626s ago] {'STATION_NAME': 'Sunnyside Station', 'LEG': 'NW', 'DIRECTION': 'North/South', 'DIST_NB': 1026.0, 'DIST_SB': 1147.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0843925 51.0562604)'}
# 2024-03-20 18:01:51,279 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,294 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,301 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,301 INFO sqlalchemy.engine.Engine [cached since 0.4889s ago] {'STATION_NAME': 'Canyon Meadows Station', 'LEG': 'SW', 'DIRECTION': 'North/South', 'DIST_NB': 2041.0, 'DIST_SB': 1505.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0697921 50.9359154)'}
# 2024-03-20 18:01:51,309 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,327 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,333 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,333 INFO sqlalchemy.engine.Engine [cached since 0.5226s ago] {'STATION_NAME': 'Barlow/Max Bell Station', 'LEG': 'NE', 'DIRECTION': 'East/West', 'DIST_NB': 0.0, 'DIST_SB': 0.0, 'DIST_EB': 934.0, 'DIST_WB': 1379.0, 'ROUTE': '202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0066132 51.0454958)'}
# 2024-03-20 18:01:51,341 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,360 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,360 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,368 INFO sqlalchemy.engine.Engine [cached since 0.5563s ago] {'STATION_NAME': 'City Hall Station', 'LEG': 'DTEastbnd', 'DIRECTION': 'East', 'DIST_NB': 1392.0, 'DIST_SB': 1027.0, 'DIST_EB': 0.0, 'DIST_WB': 319.0, 'ROUTE': '201/202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0569992 51.0462137)'}
# 2024-03-20 18:01:51,376 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,384 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,393 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,393 INFO sqlalchemy.engine.Engine [cached since 0.5825s ago] {'STATION_NAME': 'Downtown West - Kerby Station', 'LEG': 'DTWestbnd', 'DIRECTION': 'West/East', 'DIST_NB': 0.0, 'DIST_SB': 0.0, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': '202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0872486 51.0472333)'}
# 2024-03-20 18:01:51,401 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,415 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,418 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,422 INFO sqlalchemy.engine.Engine [cached since 0.6092s ago] {'STATION_NAME': 'Whitehorn Station', 'LEG': 'NE', 'DIRECTION': 'North/South', 'DIST_NB': 2640.0, 'DIST_SB': 1276.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-113.9817427 51.0859557)'}
# 2024-03-20 18:01:51,427 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,436 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,460 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,460 INFO sqlalchemy.engine.Engine [cached since 0.6483s ago] {'STATION_NAME': 'Martindale Station', 'LEG': 'NE', 'DIRECTION': 'North/South', 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': '202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-113.9679024 51.1177053)'}
# 2024-03-20 18:01:51,476 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,493 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,500 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,500 INFO sqlalchemy.engine.Engine [cached since 0.688s ago] {'STATION_NAME': 'Erlton/Stampede Station', 'LEG': 'SW', 'DIRECTION': 'North/South', 'DIST_NB': 725.0, 'DIST_SB': 1669.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0589003 51.0320601)'}
# 2024-03-20 18:01:51,508 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,516 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,524 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,527 INFO sqlalchemy.engine.Engine [cached since 0.7151s ago] {'STATION_NAME': 'SAIT/ACAD/Jubilee Station', 'LEG': 'NW', 'DIRECTION': 'North/South', 'DIST_NB': 923.0, 'DIST_SB': 1026.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.091313 51.0631335)'}
# 2024-03-20 18:01:51,532 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,556 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,560 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,565 INFO sqlalchemy.engine.Engine [cached since 0.7509s ago] {'STATION_NAME': '7th Street SW Station', 'LEG': 'DTWestbnd', 'DIRECTION': 'West', 'DIST_NB': 1376.0, 'DIST_SB': 0.0, 'DIST_EB': 265.0, 'DIST_WB': 334.0, 'ROUTE': '201/202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0774251 51.0469879)'}
# 2024-03-20 18:01:51,568 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,585 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,598 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,598 INFO sqlalchemy.engine.Engine [cached since 0.7859s ago] {'STATION_NAME': 'Anderson Station', 'LEG': 'SW', 'DIRECTION': 'North/South', 'DIST_NB': 1064.0, 'DIST_SB': 2041.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0745188 50.9543165)'}
# 2024-03-20 18:01:51,618 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,644 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,651 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,651 INFO sqlalchemy.engine.Engine [cached since 0.8404s ago] {'STATION_NAME': 'Chinook Station', 'LEG': 'SW', 'DIRECTION': 'North/South', 'DIST_NB': 2299.0, 'DIST_SB': 2200.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0658085 50.9968079)'}
# 2024-03-20 18:01:51,661 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,668 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,677 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,677 INFO sqlalchemy.engine.Engine [cached since 0.8663s ago] {'STATION_NAME': '6th Street SW Station', 'LEG': 'DTEastbnd', 'DIRECTION': 'East', 'DIST_NB': 0.0, 'DIST_SB': 0.0, 'DIST_EB': 414.0, 'DIST_WB': 410.0, 'ROUTE': '201/202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0750848 51.0467732)'}
# 2024-03-20 18:01:51,686 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,694 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,703 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,703 INFO sqlalchemy.engine.Engine [cached since 0.8921s ago] {'STATION_NAME': 'Heritage Station', 'LEG': 'SW', 'DIRECTION': 'North/South', 'DIST_NB': 2200.0, 'DIST_SB': 1654.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0742715 50.9779871)'}
# 2024-03-20 18:01:51,710 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,718 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,726 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,726 INFO sqlalchemy.engine.Engine [cached since 0.9142s ago] {'STATION_NAME': 'Downtown West - Kerby Station', 'LEG': 'DTEastbnd', 'DIRECTION': 'East', 'DIST_NB': 0.0, 'DIST_SB': 0.0, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': '202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0872437 51.0471263)'}
# 2024-03-20 18:01:51,735 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,744 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,751 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,751 INFO sqlalchemy.engine.Engine [cached since 0.9408s ago] {'STATION_NAME': 'Tuscany Station', 'LEG': 'NW', 'DIRECTION': 'North/South', 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.2355599 51.1344705)'}
# 2024-03-20 18:01:51,759 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,768 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,777 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,777 INFO sqlalchemy.engine.Engine [cached since 0.9673s ago] {'STATION_NAME': 'University Station', 'LEG': 'NW', 'DIRECTION': 'North/South', 'DIST_NB': 1013.0, 'DIST_SB': 1130.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.1229092 51.0800023)'}
# 2024-03-20 18:01:51,784 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,794 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,800 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,800 INFO sqlalchemy.engine.Engine [cached since 0.9923s ago] {'STATION_NAME': 'Saddletowne Station', 'LEG': 'NE', 'DIRECTION': 'North/South', 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': '202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-113.9481535 51.1257147)'}
# 2024-03-20 18:01:51,810 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,825 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,827 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,827 INFO sqlalchemy.engine.Engine [cached since 1.018s ago] {'STATION_NAME': 'Shawnessy Station', 'LEG': 'SW', 'DIRECTION': 'North/South', 'DIST_NB': 1464.0, 'DIST_SB': 1239.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0705658 50.910573)'}
# 2024-03-20 18:01:51,833 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,849 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,849 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,857 INFO sqlalchemy.engine.Engine [cached since 1.043s ago] {'STATION_NAME': 'Banff Trail Station', 'LEG': 'NW', 'DIRECTION': 'North/South', 'DIST_NB': 1130.0, 'DIST_SB': 1220.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.1155563 51.0709541)'}
# 2024-03-20 18:01:51,861 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,873 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,877 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,877 INFO sqlalchemy.engine.Engine [cached since 1.069s ago] {'STATION_NAME': '4th Street SW Station', 'LEG': 'DTWestbnd', 'DIRECTION': 'West', 'DIST_NB': 0.0, 'DIST_SB': 0.0, 'DIST_EB': 439.0, 'DIST_WB': 1.0, 'ROUTE': '201/202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0726676 51.0468366)'}
# 2024-03-20 18:01:51,889 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,903 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,911 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,917 INFO sqlalchemy.engine.Engine [cached since 1.102s ago] {'STATION_NAME': 'Rundle Station', 'LEG': 'NE', 'DIRECTION': 'North/South', 'DIST_NB': 1276.0, 'DIST_SB': 1845.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-113.9817251 51.0758603)'}
# 2024-03-20 18:01:51,918 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,934 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,943 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,944 INFO sqlalchemy.engine.Engine [cached since 1.131s ago] {'STATION_NAME': 'Zoo Station', 'LEG': 'NE', 'DIRECTION': 'East/West', 'DIST_NB': 0.0, 'DIST_SB': 0.0, 'DIST_EB': 1379.0, 'DIST_WB': 1100.0, 'ROUTE': '202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0248561 51.0473692)'}
# 2024-03-20 18:01:51,961 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:51,975 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:51,984 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:51,984 INFO sqlalchemy.engine.Engine [cached since 1.174s ago] {'STATION_NAME': '39 Avenue Station', 'LEG': 'SW', 'DIRECTION': 'North/South', 'DIST_NB': 1669.0, 'DIST_SB': 2299.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0613831 51.017567)'}
# 2024-03-20 18:01:51,994 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,008 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,008 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,016 INFO sqlalchemy.engine.Engine [cached since 1.202s ago] {'STATION_NAME': 'Victoria Park/Stampede Station', 'LEG': 'SW', 'DIRECTION': 'North/South', 'DIST_NB': 1027.0, 'DIST_SB': 725.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0583081 51.0385801)'}
# 2024-03-20 18:01:52,024 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,044 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,052 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,052 INFO sqlalchemy.engine.Engine [cached since 1.24s ago] {'STATION_NAME': 'Franklin Station', 'LEG': 'NE', 'DIRECTION': 'East/West', 'DIST_NB': 0.0, 'DIST_SB': 0.0, 'DIST_EB': 1723.0, 'DIST_WB': 934.0, 'ROUTE': '202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-113.9938962 51.0475332)'}
# 2024-03-20 18:01:52,060 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,095 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,104 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,107 INFO sqlalchemy.engine.Engine [cached since 1.294s ago] {'STATION_NAME': 'Crowfoot Station', 'LEG': 'NW', 'DIRECTION': 'North/South', 'DIST_NB': 0.0, 'DIST_SB': 3966.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.2065522 51.1224264)'}
# 2024-03-20 18:01:52,125 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,149 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,157 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,157 INFO sqlalchemy.engine.Engine [cached since 1.345s ago] {'STATION_NAME': 'Westbrook Station', 'LEG': 'West', 'DIRECTION': 'West/East', 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': '202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.1363619 51.0401971)'}
# 2024-03-20 18:01:52,165 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,181 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,189 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,189 INFO sqlalchemy.engine.Engine [cached since 1.378s ago] {'STATION_NAME': 'Somerset-Bridlewood Station', 'LEG': 'SW', 'DIRECTION': 'North/South', 'DIST_NB': 1239.0, 'DIST_SB': 0.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0690009 50.8990881)'}
# 2024-03-20 18:01:52,198 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,210 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,217 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,217 INFO sqlalchemy.engine.Engine [cached since 1.405s ago] {'STATION_NAME': 'McKnight Westwinds Station', 'LEG': 'NE', 'DIRECTION': 'North/South', 'DIST_NB': 0.0, 'DIST_SB': 2640.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-113.9756529 51.109224)'}
# 2024-03-20 18:01:52,235 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,259 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,267 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,267 INFO sqlalchemy.engine.Engine [cached since 1.46s ago] {'STATION_NAME': 'Brentwood Station', 'LEG': 'NW', 'DIRECTION': 'North/South', 'DIST_NB': 2372.0, 'DIST_SB': 1013.0, 'DIST_EB': 0.0, 'DIST_WB': 0.0, 'ROUTE': '201', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.1318034 51.0870474)'}
# 2024-03-20 18:01:52,277 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,300 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,310 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,310 INFO sqlalchemy.engine.Engine [cached since 1.499s ago] {'STATION_NAME': 'Shaganappi Point Station', 'LEG': 'West', 'DIRECTION': 'West/East', 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': '202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.1250072 51.0416835)'}
# 2024-03-20 18:01:52,317 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,360 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,360 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,368 INFO sqlalchemy.engine.Engine [cached since 1.553s ago] {'STATION_NAME': '3rd Street SW Station', 'LEG': 'DTEastbnd', 'DIRECTION': 'East', 'DIST_NB': 0.0, 'DIST_SB': 0.0, 'DIST_EB': 544.0, 'DIST_WB': 414.0, 'ROUTE': '201/202', 'STATUS': 'Current', 'LRT_POINT': 'POINT (-114.0692625 51.046613)'}
# 2024-03-20 18:01:52,368 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Loop through DataFrame rows and insert data into the database
for index, row in df_green_lrt.iterrows():
    try:
        lrt_station = TransitLRTStation(
            STATION_NAME=row['STATION_NAME'],
            STATUS=row['STATUS'],
            LEG=row['LEG'],
            LRT_POINT=row['LRT_POINT']
        )
        session.add(lrt_station)
        session.commit()  # Commit the transaction

    except Exception as e:
        print(f"Error in row {index}: {e}")
        print(row)  # Print the entire row for reference
        session.rollback()  # Rollback the transaction to continue with the next row
# Out:
# 2024-03-20 18:01:52,425 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,427 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,434 INFO sqlalchemy.engine.Engine [cached since 1.62s ago] {'STATION_NAME': 'Douglas Glen', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-113.9969718 50.9522514)'}
# 2024-03-20 18:01:52,434 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,444 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,458 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,458 INFO sqlalchemy.engine.Engine [cached since 1.648s ago] {'STATION_NAME': 'Ogden', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-113.9993304 50.9891256)'}
# 2024-03-20 18:01:52,474 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,482 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,490 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,490 INFO sqlalchemy.engine.Engine [cached since 1.678s ago] {'STATION_NAME': '144 Avenue N', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0713029 51.1807479)'}
# 2024-03-20 18:01:52,499 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,515 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,523 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,527 INFO sqlalchemy.engine.Engine [cached since 1.714s ago] {'STATION_NAME': 'Eau Claire', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0678645 51.0523555)'}
# 2024-03-20 18:01:52,531 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,550 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,550 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,550 INFO sqlalchemy.engine.Engine [cached since 1.744s ago] {'STATION_NAME': '4 Street SE', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0496686 51.0419951)'}
# 2024-03-20 18:01:52,562 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,578 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,585 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,585 INFO sqlalchemy.engine.Engine [cached since 1.774s ago] {'STATION_NAME': '40 Avenue N', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0624316 51.0878946)'}
# 2024-03-20 18:01:52,594 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,601 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,610 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,610 INFO sqlalchemy.engine.Engine [cached since 1.801s ago] {'STATION_NAME': '26 Avenue SE', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0362427 51.0296171)'}
# 2024-03-20 18:01:52,618 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,644 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,644 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,651 INFO sqlalchemy.engine.Engine [cached since 1.839s ago] {'STATION_NAME': 'Prestwick', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-113.9586319 50.9263123)'}
# 2024-03-20 18:01:52,651 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,678 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,684 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,692 INFO sqlalchemy.engine.Engine [cached since 1.877s ago] {'STATION_NAME': 'South Hill', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-113.994245 50.9767165)'}
# 2024-03-20 18:01:52,694 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,708 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,716 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,716 INFO sqlalchemy.engine.Engine [cached since 1.909s ago] {'STATION_NAME': 'Auburn Bay / Mahogany', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-113.943204 50.8947554)'}
# 2024-03-20 18:01:52,744 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,749 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,757 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,760 INFO sqlalchemy.engine.Engine [cached since 1.947s ago] {'STATION_NAME': 'Mcknight Boulevard', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0624368 51.1018159)'}
# 2024-03-20 18:01:52,765 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,794 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,795 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,795 INFO sqlalchemy.engine.Engine [cached since 1.989s ago] {'STATION_NAME': 'Hospital', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-113.9482276 50.8797165)'}
# 2024-03-20 18:01:52,810 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,822 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,827 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,830 INFO sqlalchemy.engine.Engine [cached since 2.017s ago] {'STATION_NAME': '28 Avenue N', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0625375 51.0787719)'}
# 2024-03-20 18:01:52,830 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,846 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,846 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,846 INFO sqlalchemy.engine.Engine [cached since 2.04s ago] {'STATION_NAME': 'McKenzie Towne', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-113.9572336 50.9154756)'}
# 2024-03-20 18:01:52,861 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,871 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,879 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,879 INFO sqlalchemy.engine.Engine [cached since 2.067s ago] {'STATION_NAME': '9 Avenue N', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0625291 51.0599413)'}
# 2024-03-20 18:01:52,887 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,895 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,903 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,911 INFO sqlalchemy.engine.Engine [cached since 2.097s ago] {'STATION_NAME': 'North Pointe', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0703571 51.1593647)'}
# 2024-03-20 18:01:52,911 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,927 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,935 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,935 INFO sqlalchemy.engine.Engine [cached since 2.124s ago] {'STATION_NAME': 'Lynnwood / Millican', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0092918 50.9991781)'}
# 2024-03-20 18:01:52,944 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,959 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,961 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,961 INFO sqlalchemy.engine.Engine [cached since 2.153s ago] {'STATION_NAME': '160 Avenue N', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0713131 51.193996)'}
# 2024-03-20 18:01:52,968 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:52,984 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:52,984 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:52,992 INFO sqlalchemy.engine.Engine [cached since 2.178s ago] {'STATION_NAME': 'Quarry Park', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0013137 50.9627627)'}
# 2024-03-20 18:01:52,994 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:53,008 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:53,016 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:53,016 INFO sqlalchemy.engine.Engine [cached since 2.204s ago] {'STATION_NAME': 'Seton', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-113.9538577 50.8720863)'}
# 2024-03-20 18:01:53,024 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:53,035 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:53,038 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:53,044 INFO sqlalchemy.engine.Engine [cached since 2.231s ago] {'STATION_NAME': '96 Avenue N', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0678585 51.1432709)'}
# 2024-03-20 18:01:53,044 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:53,060 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:53,068 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:53,068 INFO sqlalchemy.engine.Engine [cached since 2.256s ago] {'STATION_NAME': '7 Avenue SW', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0677945 51.0475185)'}
# 2024-03-20 18:01:53,076 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:53,084 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:53,097 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:53,097 INFO sqlalchemy.engine.Engine [cached since 2.285s ago] {'STATION_NAME': '16 Avenue N', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0624934 51.0661771)'}
# 2024-03-20 18:01:53,101 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:53,111 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:53,117 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:53,117 INFO sqlalchemy.engine.Engine [cached since 2.308s ago] {'STATION_NAME': 'Ramsay / Inglewood', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0365419 51.0384657)'}
# 2024-03-20 18:01:53,127 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:53,145 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:53,160 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:53,160 INFO sqlalchemy.engine.Engine [cached since 2.349s ago] {'STATION_NAME': 'Centre Street S', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0632278 51.0423902)'}
# 2024-03-20 18:01:53,166 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:53,174 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:53,182 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:53,182 INFO sqlalchemy.engine.Engine [cached since 2.374s ago] {'STATION_NAME': 'Shepard', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-113.9663081 50.9360282)'}
# 2024-03-20 18:01:53,194 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:53,199 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:53,210 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:53,210 INFO sqlalchemy.engine.Engine [cached since 2.399s ago] {'STATION_NAME': 'Beddington', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0714058 51.1276836)'}
# 2024-03-20 18:01:53,223 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:53,244 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:53,247 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:53,247 INFO sqlalchemy.engine.Engine [cached since 2.438s ago] {'STATION_NAME': 'Highfield', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.0325049 51.0201969)'}
# 2024-03-20 18:01:53,260 INFO sqlalchemy.engine.Engine COMMIT
# 2024-03-20 18:01:53,272 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-03-20 18:01:53,280 INFO sqlalchemy.engine.Engine INSERT INTO transit_lrt_stations (`STATION_NAME`, `LEG`, `DIRECTION`, `DIST_NB`, `DIST_SB`, `DIST_EB`, `DIST_WB`, `ROUTE`, `STATUS`, `LRT_POINT`) VALUES (%(STATION_NAME)s, %(LEG)s, %(DIRECTION)s, %(DIST_NB)s, %(DIST_SB)s, %(DIST_EB)s, %(DIST_WB)s, %(ROUTE)s, %(STATUS)s, ST_GeomFromText(%(LRT_POINT)s, 4326))
# 2024-03-20 18:01:53,280 INFO sqlalchemy.engine.Engine [cached since 2.468s ago] {'STATION_NAME': '64 Avenue N', 'LEG': 'Green', 'DIRECTION': None, 'DIST_NB': None, 'DIST_SB': None, 'DIST_EB': None, 'DIST_WB': None, 'ROUTE': None, 'STATUS': 'Future', 'LRT_POINT': 'POINT (-114.063834 51.1128179)'}
# 2024-03-20 18:01:53,288 INFO sqlalchemy.engine.Engine COMMIT

# %%
session.close()
#close the session, end of script
